# %%
import pandas as pd
import shapefile
import matplotlib.pyplot as plt
import geopandas as gpd
import pysal as ps
import pylab as plot
import numpy as np
import pickle
import geocoder
import string

from shapely.geometry import shape


# %matplotlib inline
pd.options.mode.chained_assignment = None  # default='warn'

# %%
gdf_medicare = pd.read_pickle('gdf_medicare')

# %%
gdf_medicare.head()
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code Hospital Referral Region Description  \
# 0             AL              36301                          AL - Dothan
# 1             AL              35957                      AL - Birmingham
# 2             AL              35631                      AL - Birmingham
# 3             AL              35235                      AL - Birmingham
# 4             AL              35007                      AL - Birmingham
#
#    Total Discharges   Average Covered Charges   Average Total Payments   \
# 0                 91                $32,963.07                $5,777.24
# 1                 14                $15,131.85                $5,787.57
# 2                 24                $37,560.37                $5,434.95
# 3                 25                $13,998.28                $5,417.56
# 4                 18                $31,633.27                $5,658.33
#
#   Average Medicare Payments                               long_lat  \
# 0                 $4,763.73  (-85.3928604125977, 31.2167854309082)
# 1                 $4,976.71  (-86.3727798461914, 34.1399955749512)
# 2                 $4,453.79  (-87.6751022338867, 34.8017730712891)
# 3                 $4,129.16   (-86.636100769043, 33.6505241394043)
# 4                 $4,851.44  (-86.8290939331055, 33.2154388427734)
#
#                                       geometry
# 0   POINT (-85.3928604125977 31.2167854309082)
# 1  POINT (-86.37277984619141 34.1399955749512)
# 2   POINT (-87.6751022338867 34.8017730712891)
# 3    POINT (-86.636100769043 33.6505241394043)
# 4   POINT (-86.8290939331055 33.2154388427734)

# %%
gdf_medicare['city_state'] = gdf_medicare['Provider City'] + ', ' + gdf_medicare['Provider State']

# %%
gdf_hrr = pd.read_pickle('Dataframes/gdf_hrr')

# %%
gdf_hrr.head()
# Out:
#           HRRCITY  HRRNUM  HRR_BDRY_I  \
# 0  AL- BIRMINGHAM       1           1
# 1      AL- DOTHAN       2           2
# 2  AL- HUNTSVILLE       5           3
# 3      AL- MOBILE       6           4
# 4  AL- MONTGOMERY       7           5
#
#                                             geometry
# 0  (POLYGON ((-85.89658 32.70483, -85.90771000000...
# 1  (POLYGON ((-86.194 31.43991, -86.1947800000000...
# 2  (POLYGON ((-86.69474000000001 34.42309, -86.71...
# 3  (POLYGON ((-87.55554000000001 30.47282, -87.56...
# 4  POLYGON ((-86.49925 31.52517, -86.642280000000...

# %%
gdf_medicare.columns
# Out:
# Index(['DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Hospital Referral Region Description',
#        ' Total Discharges ', ' Average Covered Charges ',
#        ' Average Total Payments ', 'Average Medicare Payments', 'long_lat',
#        'geometry', 'city_state'],
#       dtype='object')

# %%
gdf_medicare.rename(columns={' Total Discharges ': 'Total Discharges', \
                         ' Average Covered Charges ': 'Average Covered Charges',\
                  ' Average Total Payments ' : 'Average Total Payments' }, inplace=True)

# %%
numerical_col = ['Total Discharges', 'Average Covered Charges', 'Average Total Payments', 'Average Medicare Payments']

# %%
gdf_medicare[numerical_col] = \
gdf_medicare[numerical_col].apply(lambda x: x.str.replace('[\$,]', ''))

# %%
gdf_medicare[numerical_col] = \
gdf_medicare[numerical_col].apply(lambda x: x.astype(float))

# %%
numerical_dict = dict.fromkeys(numerical_col, 'mean')

# %%
numerical_dict
# Out:
# {'Average Covered Charges': 'mean',
#  'Average Medicare Payments': 'mean',
#  'Average Total Payments': 'mean',
#  'Total Discharges': 'mean'}

# %%
df_mean = gdf_medicare.groupby(['Hospital Referral Region Description']\
                                            ,as_index=False).agg(numerical_dict)

# %%
df_mean['Hospital Referral Region Description'] = \
df_mean['Hospital Referral Region Description'].apply(lambda x: x.replace(' ', ''))

# %%
df_mean['Hospital Referral Region Description'] = \
df_mean['Hospital Referral Region Description'].apply(lambda x: x.upper())

# %%
gdf_hrr['HRRCITY_cleaned'] = gdf_hrr['HRRCITY']

gdf_hrr['HRRCITY_cleaned'] = \
gdf_hrr['HRRCITY_cleaned'].apply(lambda x: x.replace(' ', ''))

gdf_hrr['HRRCITY_cleaned'] = \
gdf_hrr['HRRCITY_cleaned'].apply(lambda x: x.upper())

# %%
gdf_hrr['HRRCITY_cleaned'] = \
gdf_hrr['HRRCITY_cleaned'].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))

df_mean['Hospital Referral Region Description'] = \
df_mean['Hospital Referral Region Description'].apply(lambda x: x.translate(str.maketrans('','',string.punctuation)))

# %%
hrr_na_update = {'CAALAMEDACOUNTY': 'CAALAMEDACO', 'CACONTRACOSTACOUNTY' : 'CACONTRACOSTACO', \
'CAORANGECOUNTY' : 'CAORANGECO', 'CAPALMSPRINGSRANCHOM' : 'CAPALMSPRRANCHOMIR'\
,'CASANMATEOCOUNTY' : 'CASANMATEOCO', 'NYMANHATTAN': 'NYNEWYORK'}

# %%
df_mean["Hospital Referral Region Description"].replace(hrr_na_update, inplace=True)

# %%
merged_hrr_gdf = pd.merge(gdf_hrr, df_mean, left_on = 'HRRCITY_cleaned', right_on = 'Hospital Referral Region Description'\
        ,how = 'outer')

# %%
merged_hrr_gdf
# Out:
#                       HRRCITY  HRRNUM  HRR_BDRY_I  \
# 0              AL- BIRMINGHAM       1           1
# 1                  AL- DOTHAN       2           2
# 2              AL- HUNTSVILLE       5           3
# 3                  AL- MOBILE       6           4
# 4              AL- MONTGOMERY       7           5
# 5              AL- TUSCALOOSA       9           6
# 6                AK-Anchorage      10           7
# 7                    AZ- MESA      11           8
# 8                 AZ- PHOENIX      12           9
# 9                AZ- SUN CITY      14          10
# 10                 AZ- TUCSON      15          11
# 11             AR- FORT SMITH      16          12
# 12              AR- JONESBORO      18          13
# 13            AR- LITTLE ROCK      19          14
# 14             AR- SPRINGDALE      21          15
# 15              AR- TEXARKANA      22          16
# 16             CA- ORANGE CO.      23          17
# 17            CA- BAKERSFIELD      25          18
# 18                  CA- CHICO      31          19
# 19       CA- CONTRA COSTA CO.      33          20
# 20                 CA- FRESNO      43          21
# 21            CA- LOS ANGELES      56          22
# 22                CA- MODESTO      58          23
# 23                   CA- NAPA      62          24
# 24            CA- ALAMEDA CO.      65          25
# 25   CA- PALM SPR/RANCHO MIR.      69          26
# 26                CA- REDDING      73          27
# 27             CA- SACRAMENTO      77          28
# 28                CA- SALINAS      78          29
# 29         CA- SAN BERNARDINO      79          30
# ..                        ...     ...         ...
# 276                 UT- OGDEN     421         277
# 277                 UT- PROVO     422         278
# 278        UT- SALT LAKE CITY     423         279
# 279            VT- BURLINGTON     424         280
# 280             VA- ARLINGTON     426         281
# 281       VA- CHARLOTTESVILLE     427         282
# 282             VA- LYNCHBURG     428         283
# 283          VA- NEWPORT NEWS     429         284
# 284               VA- NORFOLK     430         285
# 285              VA- RICHMOND     431         286
# 286               VA- ROANOKE     432         287
# 287            VA- WINCHESTER     435         288
# 288               WA- EVERETT     437         289
# 289               WA- OLYMPIA     438         290
# 290               WA- SEATTLE     439         291
# 291               WA- SPOKANE     440         292
# 292                WA- TACOMA     441         293
# 293                WA- YAKIMA     442         294
# 294            WV- CHARLESTON     443         295
# 295            WV- HUNTINGTON     444         296
# 296            WV- MORGANTOWN     445         297
# 297              WI- APPLETON     446         298
# 298             WI- GREEN BAY     447         299
# 299             WI- LA CROSSE     448         300
# 300               WI- MADISON     449         301
# 301            WI- MARSHFIELD     450         302
# 302             WI- MILWAUKEE     451         303
# 303                WI- NEENAH     452         304
# 304                WI- WAUSAU     456         305
# 305                WY- CASPER     457         306
#
#                                               geometry     HRRCITY_cleaned  \
# 0    (POLYGON ((-85.89658 32.70483, -85.90771000000...        ALBIRMINGHAM
# 1    (POLYGON ((-86.194 31.43991, -86.1947800000000...            ALDOTHAN
# 2    (POLYGON ((-86.69474000000001 34.42309, -86.71...        ALHUNTSVILLE
# 3    (POLYGON ((-87.55554000000001 30.47282, -87.56...            ALMOBILE
# 4    POLYGON ((-86.49925 31.52517, -86.642280000000...        ALMONTGOMERY
# 5    POLYGON ((-87.31229 33.08598, -87.308500000000...        ALTUSCALOOSA
# 6    (POLYGON ((-105.627887 29.245417, -105.627887 ...         AKANCHORAGE
# 7    POLYGON ((-111.21145 33.08493, -111.21638 33.0...              AZMESA
# 8    (POLYGON ((-111.5151 33.01583, -111.51156 33.0...           AZPHOENIX
# 9    POLYGON ((-112.40912 33.63857, -112.4542 33.63...           AZSUNCITY
# 10   POLYGON ((-109.04923 31.49941, -109.04944 31.3...            AZTUCSON
# 11   POLYGON ((-95.05921000000001 34.83756, -95.060...         ARFORTSMITH
# 12   POLYGON ((-90.10436000000001 36.40546000000001...         ARJONESBORO
# 13   (POLYGON ((-91.45942000000001 36.1603, -91.454...        ARLITTLEROCK
# 14   POLYGON ((-93.65746000000001 36.30301, -93.665...        ARSPRINGDALE
# 15   POLYGON ((-94.66656 34.19471, -94.66449 34.194...         ARTEXARKANA
# 16   (POLYGON ((-117.67286 33.87082, -117.67056 33....          CAORANGECO
# 17   POLYGON ((-119.53716 35.78961, -119.53375 35.9...       CABAKERSFIELD
# 18   (POLYGON ((-121.86901 39.46431, -121.87376 39....             CACHICO
# 19   (POLYGON ((-122.09466 38.04844000000001, -122....     CACONTRACOSTACO
# 20   POLYGON ((-119.52844 36.15236, -119.51885 36.1...            CAFRESNO
# 21   (POLYGON ((-117.8593 33.9771, -117.8654 33.973...        CALOSANGELES
# 22   POLYGON ((-119.95131 37.65128, -119.94729 37.6...           CAMODESTO
# 23   POLYGON ((-122.491 38.4546, -122.4926 38.4566,...              CANAPA
# 24   (POLYGON ((-122.3002 37.8474, -122.2996 37.850...         CAALAMEDACO
# 25   POLYGON ((-116.5116 33.6521, -116.5116 33.6849...  CAPALMSPRRANCHOMIR
# 26   (POLYGON ((-123.28526 40.71239000000001, -123....           CAREDDING
# 27   POLYGON ((-120.66426 39.30988, -120.65988 39.3...        CASACRAMENTO
# 28   POLYGON ((-121.43812 36.09952000000001, -121.4...           CASALINAS
# 29   POLYGON ((-116.20274 35.04538, -116.21415 35.0...     CASANBERNARDINO
# ..                                                 ...                 ...
# 276  (POLYGON ((-111.83287 41.03705, -111.84945 41....             UTOGDEN
# 277  POLYGON ((-112.51443 38.57236, -112.51813 38.5...             UTPROVO
# 278  (POLYGON ((-111.0432 43.14374, -111.04385 43.3...      UTSALTLAKECITY
# 279  (POLYGON ((-74.7266 44.99481, -74.722950000000...        VTBURLINGTON
# 280  POLYGON ((-77.1202 38.9342, -77.1182 38.932300...         VAARLINGTON
# 281  POLYGON ((-78.33859000000001 38.62716, -78.335...   VACHARLOTTESVILLE
# 282  POLYGON ((-79.47162 37.54797000000001, -79.463...         VALYNCHBURG
# 283  (POLYGON ((-76.50883 37.26469, -76.50901 37.26...       VANEWPORTNEWS
# 284  (POLYGON ((-76.64316000000001 36.39452, -76.66...           VANORFOLK
# 285  (POLYGON ((-78.44135 36.91378, -78.44169000000...          VARICHMOND
# 286  POLYGON ((-79.61841000000001 37.85989, -79.606...           VAROANOKE
# 287  POLYGON ((-78.28515 38.75911, -78.290820000000...        VAWINCHESTER
# 288  (POLYGON ((-121.0002 48.2957, -120.9989 48.290...           WAEVERETT
# 289  (POLYGON ((-122.46383 46.66741, -122.46622 46....           WAOLYMPIA
# 290  (POLYGON ((-123.346 47.60727000000001, -123.35...           WASEATTLE
# 291  (POLYGON ((-117.03128 48.99926000000001, -116....           WASPOKANE
# 292  (POLYGON ((-122.3399 47.2141, -122.3533 47.221...            WATACOMA
# 293  POLYGON ((-119.87281 46.62692000000001, -119.8...            WAYAKIMA
# 294  (POLYGON ((-80.30030000000001 39.1038, -80.248...        WVCHARLESTON
# 295  (POLYGON ((-82.59469 38.41554, -82.58362000000...        WVHUNTINGTON
# 296  POLYGON ((-80.51954000000001 39.72132000000001...        WVMORGANTOWN
# 297  POLYGON ((-88.42385 44.69166000000001, -88.423...          WIAPPLETON
# 298  (POLYGON ((-87.76254 44.96563, -87.78204000000...          WIGREENBAY
# 299  POLYGON ((-91.96296000000001 43.08239, -91.963...          WILACROSSE
# 300  POLYGON ((-89.12634000000001 43.67417, -89.110...           WIMADISON
# 301  POLYGON ((-91.00410000000001 44.70601000000001...        WIMARSHFIELD
# 302  POLYGON ((-87.80049000000001 42.4919, -87.798 ...         WIMILWAUKEE
# 303  (POLYGON ((-88.88595000000001 43.63361, -88.92...            WINEENAH
# 304  POLYGON ((-89.30141 45.46939, -89.301150000000...            WIWAUSAU
# 305  POLYGON ((-107.59447 43.50144, -107.53427 43.5...            WYCASPER
#
#     Hospital Referral Region Description  Total Discharges  \
# 0                           ALBIRMINGHAM         36.255715
# 1                               ALDOTHAN         38.452941
# 2                           ALHUNTSVILLE         51.631450
# 3                               ALMOBILE         41.545290
# 4                           ALMONTGOMERY         33.720548
# 5                           ALTUSCALOOSA         55.796512
# 6                            AKANCHORAGE         26.588745
# 7                                 AZMESA         41.142276
# 8                              AZPHOENIX         33.595128
# 9                              AZSUNCITY         59.544503
# 10                              AZTUCSON         34.658182
# 11                           ARFORTSMITH         38.716000
# 12                           ARJONESBORO         40.749020
# 13                          ARLITTLEROCK         43.932937
# 14                          ARSPRINGDALE         37.738676
# 15                           ARTEXARKANA         35.914286
# 16                            CAORANGECO         34.702321
# 17                         CABAKERSFIELD         36.628692
# 18                               CACHICO         41.213389
# 19                       CACONTRACOSTACO         32.124294
# 20                              CAFRESNO         52.891429
# 21                          CALOSANGELES         38.673419
# 22                             CAMODESTO         36.657534
# 23                                CANAPA         30.760000
# 24                           CAALAMEDACO         34.549495
# 25                    CAPALMSPRRANCHOMIR         44.892308
# 26                             CAREDDING         36.537445
# 27                          CASACRAMENTO         37.797342
# 28                             CASALINAS         35.666667
# 29                       CASANBERNARDINO         30.822816
# ..                                   ...               ...
# 276                              UTOGDEN         29.680328
# 277                              UTPROVO         29.264151
# 278                       UTSALTLAKECITY         31.352041
# 279                         VTBURLINGTON         34.896552
# 280                          VAARLINGTON         42.369902
# 281                    VACHARLOTTESVILLE         47.268354
# 282                          VALYNCHBURG         81.289256
# 283                        VANEWPORTNEWS         39.710059
# 284                            VANORFOLK         42.836000
# 285                           VARICHMOND         45.513678
# 286                            VAROANOKE         43.174603
# 287                         VAWINCHESTER         56.340541
# 288                            WAEVERETT         37.978723
# 289                            WAOLYMPIA         39.963636
# 290                            WASEATTLE         38.161572
# 291                            WASPOKANE         35.507508
# 292                             WATACOMA         42.501319
# 293                             WAYAKIMA         36.160000
# 294                         WVCHARLESTON         45.649351
# 295                         WVHUNTINGTON         52.566489
# 296                         WVMORGANTOWN         37.455696
# 297                           WIAPPLETON         26.183908
# 298                           WIGREENBAY         25.912226
# 299                           WILACROSSE         28.173333
# 300                            WIMADISON         36.726644
# 301                         WIMARSHFIELD         31.689119
# 302                          WIMILWAUKEE         40.481910
# 303                             WINEENAH         27.132530
# 304                             WIWAUSAU         31.468531
# 305                             WYCASPER         25.548673
#
#      Average Covered Charges  Average Total Payments  \
# 0               35875.130728             7724.118841
# 1               27610.974000             7038.365971
# 2               28310.887690             7517.767617
# 3               28951.019982             7639.114946
# 4               25152.752548             7620.635288
# 5               26422.386919             8352.626628
# 6               40348.743333            14572.391732
# 7               46567.402297             9775.701687
# 8               39288.264806            10629.743436
# 9               43732.348796             8589.015288
# 10              37479.413127            10120.504073
# 11              23675.513240             7610.662960
# 12              20404.225333             8005.950588
# 13              27322.429737             8101.555136
# 14              30683.650279             7997.931707
# 15              29642.805952             7985.922000
# 16              60139.496004            11292.515913
# 17              52682.515274            11335.493059
# 18              58182.863264             9739.513849
# 19             100597.087825            14129.069831
# 20              43087.861914            12036.057257
# 21              68254.250964            12840.321481
# 22              84410.106986            12610.130904
# 23              67251.594867            12422.863733
# 24              82368.935354            14579.751818
# 25              77936.696308            10182.874718
# 26              61463.169868            12558.774802
# 27              66405.546777            12495.618959
# 28              65390.511530            15494.010710
# 29              51673.977330            11962.790801
# ..                       ...                     ...
# 276             24690.991230             8721.825082
# 277             24230.073396             9097.138113
# 278             25597.022670            10402.388486
# 279             19855.140591            11037.077882
# 280             24949.887876             9317.377370
# 281             25223.181316            10309.900304
# 282             20163.260248             8446.975372
# 283             24562.129734             8577.150473
# 284             27522.206827             8844.300027
# 285             43627.804113             9416.463617
# 286             24061.434109             7993.669277
# 287             17706.696432             9018.393676
# 288             29934.522500             9318.087979
# 289             39638.494061            10036.776909
# 290             35402.469109            11274.353948
# 291             28140.309625            10117.682357
# 292             46748.576359            10524.680976
# 293             26162.223467             9184.758733
# 294             19645.197835             7604.731746
# 295             23601.855612             8535.742793
# 296             19295.390278             8609.392532
# 297             16489.769425             8818.886897
# 298             22162.551223             8106.950282
# 299             22052.841000             9026.790400
# 300             28850.397526             9951.002785
# 301             21312.991865             9314.504819
# 302             30707.213603             9282.607135
# 303             16663.854819             7637.691566
# 304             24126.254685             9077.712867
# 305             31045.165044            11083.336372
#
#      Average Medicare Payments
# 0                  6577.098107
# 1                  6012.843618
# 2                  6194.050393
# 3                  6356.235942
# 4                  6572.985890
# 5                  7292.552209
# 6                 12958.969437
# 7                  8317.502866
# 8                  9213.646886
# 9                  7549.713141
# 10                 9051.569709
# 11                 6574.489360
# 12                 6982.240196
# 13                 7021.016171
# 14                 6695.870139
# 15                 6849.453381
# 16                10131.079132
# 17                10242.007489
# 18                 8838.792720
# 19                12838.389379
# 20                10679.853286
# 21                11797.551443
# 22                11535.746219
# 23                11419.640867
# 24                13581.371717
# 25                 9063.510000
# 26                11460.687841
# 27                11114.224928
# 28                13654.026667
# 29                10941.813119
# ..                         ...
# 276                7121.293770
# 277                7422.575943
# 278                8464.848912
# 279                9940.964039
# 280                7920.417609
# 281                8937.429241
# 282                7001.473388
# 283                7379.169467
# 284                7537.335080
# 285                7967.387751
# 286                6699.605132
# 287                7732.938324
# 288                7919.220957
# 289                8263.523636
# 290                9805.164550
# 291                8800.698063
# 292                8996.351266
# 293                7795.700333
# 294                6501.012121
# 295                7503.658564
# 296                7561.406962
# 297                7554.279080
# 298                6775.825455
# 299                7956.879000
# 300                8711.636125
# 301                7992.684249
# 302                8005.432496
# 303                6443.587108
# 304                7749.684476
# 305                8670.711150
#
# [306 rows x 10 columns]

# %%
merged_hrr_gdf[merged_hrr_gdf.isnull().any(axis=1)]
# Out:
# Empty GeoDataFrame
# Columns: [HRRCITY, HRRNUM, HRR_BDRY_I, geometry, HRRCITY_cleaned, Hospital Referral Region Description, Total Discharges, Average Covered Charges, Average Total Payments, Average Medicare Payments]
# Index: []
